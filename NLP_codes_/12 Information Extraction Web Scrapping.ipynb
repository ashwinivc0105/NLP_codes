# %%
import urllib

# %%
url = urllib.request.urlopen('https://en.wikipedia.org/wiki/Cricket')

# %%
url

# %%
data = url.read()

# %%
print(data)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Cricket - Wikipedia</title>\n<script>document.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled";(function(){var cookie=document.cookie.match(/(?:^|; )enwikimwclientpr
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data, 'lxml')

# %%
text = soup.get_text(strip=True)

# %%
text
# Out:
# 'Cricket - Wikipediadocument.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled";(function(){var cookie=document.cookie.match(/(?:^|; )enwikimwclientprefs=([^;]+)/);if(cookie){var featureName=cookie[1];document.documentElement.className=document.documentElement.className.replace(featureName+\'-enabled\',featureName+\'-disabled\');}}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"eee3165b-bdd2-4d40-8b1f-03b7b4d240
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import FreqDist
import string

# %%
url = urllib.request.urlopen('https://mr.wikipedia.org/wiki/Wikipedia')
data = url.read()

soup = BeautifulSoup(data, 'lxml')
text = soup.get_text(strip=True)

tokens = word_tokenize(text)
swords = stopwords.words('english')

tokens1 = [x.lower() for x in tokens if x.isalpha() or x.isdigit()]
tokens2 = [x for x in tokens1 if x not in swords]

freq = FreqDist(tokens2)
freq.plot(10)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
# !pip install pygooglenews
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f085cbc35b0>: Failed to establish a new connection: [Errno -2] Name or service not known')': /simple/pygooglenews/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f085cbc38b0>: Failed to establish a new connection: [Errno -2] Name or service not known')': /simple/pygooglenews/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.0/362.0 kB 3.0 MB/s eta 0:00:00m eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 2.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...

# %%
from pygooglenews import GoogleNews

# %%
gn = GoogleNews()
s = gn.search('Intercontinental Cup')

for entry in s["entries"]:
    print(entry["title"])
# Out:
# Intercontinental Cup showcases India's growing depth, but it's just a start - ESPN - ESPN India
# Coach Stimac's 'tongue lashing' spurs India to title - Rediff.com
# Odisha Chief Minister Announces Rs 1 Crore Reward For Indian Football Team After Intercontinental Cu.. - NDTV Sports
# Odisha CM to give ₹1 crore to Indian football team for Intercontinental Cup victory - The Hindu
# Odisha Chief Minister to give Rs 1 crore to Indian football team for Intercontinental Cup victory - Indiatimes.com
# Hero Intercontinental Cup 2023 Final: Five talking points from India's triumph - Khel Now
# Go & create history in AFC Asian Cup: Twitterati react to India's Hero Intercontinental Cup glory - Khel Now
# The 2023 FIBA Intercontinental Cup Draw held in Singapore - Eurohoops
# Vlade Divac, Yi Jianlian and Ian Mahinmi headline 33rd FIBA Intercontinental Cup Draw in Singapore - FIBA
# Sunil Chhetri leads India to 2-0 victory over Lebanon to win Intercontinental Cup - Telegraph India
# ...
