# %%
from nltk import pos_tag, RegexpParser
from nltk.tokenize import word_tokenize

# %%
sent = 'The Moroccan fairy tale ends at the hands of France.'

# %%
tokens = word_tokenize(sent)
tags = pos_tag(tokens)
tags
# Out:
# [('The', 'DT'),
#  ('Moroccan', 'NNP'),
#  ('fairy', 'NN'),
#  ('tale', 'NN'),
#  ('ends', 'VBZ'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('hands', 'NNS'),
#  ('of', 'IN'),
#  ('France', 'NNP'),
#  ('.', '.')]

# %%
chunker = RegexpParser("""
NP: {}
P: {}
V: {}
PP: {}
VP: {}
""")
result = chunker.parse(tags)

# %%
result
# Out:
# Tree('S', [('The', 'DT'), ('Moroccan', 'NNP'), ('fairy', 'NN'), ('tale', 'NN'), ('ends', 'VBZ'), ('at', 'IN'), ('the', 'DT'), ('hands', 'NNS'), ('of', 'IN'), ('France', 'NNP'), ('.', '.')])

# %%
result.draw()

# %%
print(result)
# Out:
# (S
#   The/DT
#   Moroccan/NNP
#   fairy/NN
#   tale/NN
#   ends/VBZ
#   at/IN
#   the/DT
#   hands/NNS
#   of/IN
#   France/NNP
#   ./.)

# %% [markdown]
# #### Dependency tree

# %%
sent = 'It was the biggest mistake made by him in the history'

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
# Creating Doc object
doc=nlp(sent)

# Getting dependency tags
for token in doc:
    print(token.text,'=>',token.dep_)
# Out:
# It => nsubj
# was => ROOT
# the => det
# biggest => amod
# mistake => attr
# made => acl
# by => agent
# him => pobj
# in => prep
# the => det
# history => pobj

# %% [markdown]
# #### Visualize the dependency tree

# %%
from spacy import displacy

# %%
displacy.render(doc,jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ec4639d53747432f8d1e6678ca839e8d-0" class="displacy" width="1975" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
sent = 'How it is possible?'
doc=nlp(sent)
displacy.render(doc,jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5ab46bd4d77e4a37b41acf7c12dcdce0-0" class="displacy" width="750" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">How</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
sent = 'It is how possible?'
doc=nlp(sent)
displacy.render(doc,jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="11c94d7ffa2e4ce486f3ab7cee14b3df-0" class="displacy" width="750" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
sent = 'The latest lava flows are dated at 300,000 years ago and volcanic activity may have continued into the Holocene.'
doc=nlp(sent)
displacy.render(doc,jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b2a061f17b1f44e4a7281e788e9cde95-0" class="displacy" width="3375" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">latest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...
